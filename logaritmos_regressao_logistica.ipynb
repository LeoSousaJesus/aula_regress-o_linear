# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoSousaJesus/projeto_regressao_linear/blob/main/logaritmos_regressao_logistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LOGARITMO O que é ?**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Os logaritmos são uma operação matemática fundamental que envolve a relação entre números e suas potências.<br>
#
# # Definição:
#
# ### Um logaritmo é a operação inversa da exponenciação. Enquanto a exponenciação eleva um número a uma potência, o logaritmo encontra a potência necessária para obter um determinado valor.<br><br>
#
# #### Tipos de Logaritmos:
#
# 1. Logaritmo Natural (ln): Baseado no número e (aproximadamente 2,718).<br>
#
# 2. Logaritmo Comum (log): Baseado no número 10.<br>
#
# 3. Logaritmo Binário (log2): Baseado no número 2.<br>
# <br>
#
# #### Propriedades:
#
# 1. Inversão: log(a^b) = b * log(a)
# 2. Produto: log(a * b) = log(a) + log(b)
# 3. Quociente: log(a / b) = log(a) - log(b)
# 4. Potência: log(a^b) = b * log(a)
# <br><br>
#
# #### Aplicações:
#
# - Cálculo de taxas de crescimento e decrescimento.
# - Resolução de equações exponenciais.
# - Análise de dados em escalas logarítmicas.
# - Matemática, física, química, geografia, computação, engenharia, economia e estatística.
# <br><br>
#
# #### Exemplos:
#
# 1. log(100) = 2, pois 10 elevado a 2 = 100.
# 2. ln(e) = 1, pois e^1 = e.
# 3. log2(8) = 3, pois 2^3 = 8.
# <br><br>
#
# ####Conceitos relacionados:
#
# - Exponenciação.
# - Funções exponenciais.
# - Escalas logarítmicas.

# %% [markdown]
# # Usando em Matemática

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Se considerarmos 3 Dimensões

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Usando em Geografia
#
# ## Longitude = Eixo X
# ## Latitude = Eixo Y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exemplo prático:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Logaritmos e Terremotos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Curiosidade: Logaritmo faz parte da vida cotidiana dos japoneses

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # A função logarítmica é fundamental na medição da magnitude de terremotos, pois permite expressar valores extremamente grandes em uma escala mais tratável. Aqui está como ela é utilizada:
#
# ## **Escala Richter**
#
# ### A escala Richter serve para medir a magnitude de terremotos. Ela utiliza a função logarítmica para calcular a magnitude **(M)** com base na amplitude das ondas sísmicas registradas por sismógrafos.
# <br>
#
# #**M = log10(A) + B**<br><br>
#
#
# ### Onde:
#
# - M é a magnitude do terremoto
# - A é a amplitude das ondas sísmicas
# - B é um fator constante que depende da localização e do tipo de terremoto
# <br><br>
#
# #### Escala de Magnitude de Momento
#
# A escala de magnitude de momento (Mw) é outra medida utilizada para terremotos grandes. Ela também emprega a função logarítmica:<br><br>
#
# #**Mw = 2/3 log10(M0) - 10.7**<br><br>
#
# ###Onde:
#
# - Mw é a magnitude de momento
# - M0 é o momento sísmico (produto da área de ruptura, deslizamento médio e módulo de elasticidade)<br><br>
#
# #### Características da função logarítmica na medição de magnitude:<br><br>
#
# 1. Reduz valores extremos: A função logarítmica compressa valores grandes em uma escala menor.
# 2. Permite comparação: A escala logarítmica permite comparar magnitudes de terremotos de diferentes tamanhos.
# 3. Linearidade: A relação entre a magnitude e a amplitude das ondas sísmicas é aproximadamente linear na escala logarítmica.<br><br>
#
# ####**Exemplos:**
#
# - Terremoto de 1906 em São Francisco (M 7,9): log10(A) ≈ 7,9
# - Terremoto de 2011 no Japão (M 9,1): log10(A) ≈ 9,1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**おはようございますありがとうございます**
#
# **Ohayō, arigatōgozaimasu**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # O que é Regressão Logística?
#
# ##**A Regressão Logística é um modelo estatístico que prevê a probabilidade de uma variável alvo ser igual a 1 (positiva) ou 0 (negativa), com base em uma ou mais variáveis de entrada.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Simplificando
#
# # Equação da Regressão Logística<br><br>
#
# # **p = 1 / (1 + e^(-z))**<br><br>
#
# ### onde:
# - p é a probabilidade de pertencimento à classe positiva
# - e é a base do logaritmo natural
# - z é a combinação linear das variáveis de entrada

# %% [markdown]
# # A Regressão Logística é fundamental em Inteligência Artificial, pois utiliza logaritmos para resolver problemas de classificação binária.

# %% [markdown]
# ### Principais diferenças entre Regressão Logística e Linear

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/romulosilvestre/rl_01/refs/heads/main/vendas.csv')

# %%
X = dados['Idade']
y = dados['Comprou']

# %%
X = dados['Idade'].values.reshape(-1, 1) # Transformando em uma Matriz 2D

# %%
model = LogisticRegression()

# %%
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#Regressão Logística com o dataset de vendas
# Carregando os dados de vendas
dados = pd.read_csv('https://raw.githubusercontent.com/romulosilvestre/rl_01/refs/heads/main/vendas.csv')
X_vendas = dados['Idade'].values.reshape(-1, 1)  # Transformando em uma matriz 2D
y_vendas = dados['Comprou']

# Criando e treinando o modelo
modelo_vendas = LogisticRegression()
modelo_vendas.fit(X_vendas, y_vendas)

# Gerando probabilidades para o gráfico
X_plot = np.linspace(X_vendas.min(), X_vendas.max(), 100).reshape(-1, 1)
y_prob = modelo_vendas.predict_proba(X_plot)[:, 1]

# Gráfico de dispersão para os dados de vendas
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)  # Adicionar um subplot para a primeira visualização
plt.scatter(X_vendas, y_vendas, s=2)
plt.plot(X_plot, y_prob, color='red', linewidth=2)
plt.title("Compras por idade")
plt.xlabel("Idade")
plt.ylabel("Probabilidade de compra")
plt.grid(True)

#Regressão Logística com o dataset Iris
# Carregando os dados Iris
iris = load_iris()
X_iris = iris.data[:, :2]  # Utilizando apenas duas características (comprimento e largura da sépala)
y_iris = iris.target

# Dividindo os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X_iris, y_iris, test_size=0.2, random_state=42)

# Criando e treinando o modelo
modelo_iris = LogisticRegression(max_iter=200)
modelo_iris.fit(X_train, y_train)

# Fazendo previsões
y_pred = modelo_iris.predict(X_test)

# Avaliando o modelo
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia do modelo Iris: {accuracy:.2f}")

# Gráfico de dispersão para o dataset Iris
plt.subplot(1, 2, 2)  # Segundo subplot para visualização do Iris
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='viridis', marker='o', edgecolor='k', label='Treino')
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, cmap='plasma', marker='x', edgecolor='k', label='Teste')
plt.title(f"Iris dataset (Acurácia: {accuracy:.2f})")
plt.xlabel("Comprimento da sépala")
plt.ylabel("Largura da sépala")
plt.legend()
plt.grid(True)

# Exibindo os gráficos
plt.tight_layout()
plt.show()
# Out:
# Acurácia do modelo Iris: 0.90
# <ipython-input-32-f3b801431cc4>:52: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, cmap='plasma', marker='x', edgecolor='k', label='Teste')

# %% [markdown]
# #Lembrando que o DataSet Iris é um dos conjuntos de dados utilizados na comunidade de aprendizado de máquina:
#
# #Contém informações sobre 150 amostras de flores da espécie Íris, divididas em três classes:
#
# - **setosa**
# - **versicolor**
# - **virginica**
